# %% [markdown]
# <a href="https://colab.research.google.com/github/mlerma54/HelloWorld/blob/master/helloworld2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Hello World 2')
# Out:
# Hello World 2
